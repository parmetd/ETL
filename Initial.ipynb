# %% [markdown]
# # Extract Transform Load Project (ETL)

# %% [markdown]
# ### Extracting Original data sources

# %%
import os
import utm
import pandas as pd
import matplotlib.pyplot as plt
import sqlalchemy
from sqlalchemy import create_engine
import reverse_geocoder as rg
import pprint

# %%
csv_file = "./Data Files/CWD_Surveillance_data_2000_2010.csv"
cwd_2000_2010_df = pd.read_csv(csv_file)
cwd_2000_2010_df.head()
# Out:
#    Case_ID      Province Harvest Type       ObsDate     Month_Obs  Year_Obs  \
# 0      100  Saskatchewan       Hunter  Undetermined  Undetermined      2000
# 1      101  Saskatchewan       Hunter  Undetermined  Undetermined      2001
# 2      102  Saskatchewan       Hunter  Undetermined  Undetermined      2002
# 3      103  Saskatchewan       Hunter  Undetermined  Undetermined      2003
# 4      104  Saskatchewan       Hunter  Undetermined  Undetermined      2004
#
#     Easting   Northing    Species     Sex CWD Status
# 0  580000.0  5850000.0  Mule Deer    Male   Positive
# 1  580000.0  5830000.0  Mule Deer    Male   Positive
# 2  570000.0  5830000.0  Mule Deer    Male   Positive
# 3  610000.0  5950000.0  Mule Deer  Female   Positive
# 4  590000.0  5840000.0  Mule Deer    Male   Positive

# %%
cwd_2000_2010_df['Province'].value_counts()
# Out:
# Alberta         16330
# Saskatchewan     3222
# Name: Province, dtype: int64

# %%
csv_file = "./Data Files/CWD_surveillance_validation_data_2011_2013.csv"
cwd_2011_2013_df = pd.read_csv(csv_file)
cwd_2011_2013_df.head()
# Out:
#     Case  Year  Easting  Northing CWD_Status            Species     Sex
# 0  10000  2011   432845   5849162   Negative  White-tailed Deer    Male
# 1  10001  2011   429500   5868700   Negative  White-tailed Deer    Male
# 2  10002  2011   438723   5896022   Negative  White-tailed Deer    Male
# 3  10003  2011   428623   5862820   Negative          Mule Deer    Male
# 4  10004  2011   431230   5882820   Negative          Mule Deer  Female

# %%
csv_file = "./Data Files/Census_Data.csv"
census_df = pd.read_csv(csv_file)
census_df
# Out:
#                      Province      Population
# 0   Newfoundland and Labrador     155,304.00
# 1        Prince Edward Island      57,887.00
# 2                 Nova Scotia     512,612.00
# 3               New Brunswick     195,361.00
# 4                      Quebec   3,064,452.00
# 5                     Ontario   5,255,754.00
# 6                    Manitoba     723,747.00
# 7                Saskatchewan     450,418.00
# 8                     Alberta   2,001,524.00
# 9                       Yukon      23,276.00
# 10                Yellowknife      19,234.00
# 11                    Nunavut           6,699

# %% [markdown]
# # Transform: What data cleaning or transformation was required.

# %%
#creating a new cleaned up dataframe so the two years will match and be appended
new_cwd_2000_2010_df = cwd_2000_2010_df[['Case_ID', 'Province', 'Year_Obs', 'Species', 'Sex', 'CWD Status']].copy()
new_cwd_2000_2010_df.head()
# Out:
#    Case_ID      Province  Year_Obs    Species     Sex CWD Status
# 0      100  Saskatchewan      2000  Mule Deer    Male   Positive
# 1      101  Saskatchewan      2001  Mule Deer    Male   Positive
# 2      102  Saskatchewan      2002  Mule Deer    Male   Positive
# 3      103  Saskatchewan      2003  Mule Deer  Female   Positive
# 4      104  Saskatchewan      2004  Mule Deer    Male   Positive

# %%
#Renaming columns so headers will match for append. Year is keyword in SQL so had to rename column to load.
new_cwd_2000_2010_df = new_cwd_2000_2010_df.rename(columns={"Year_Obs":"Years", "CWD Status":"CWD_Status"})
new_cwd_2000_2010_df.head()
# Out:
#    Case_ID      Province  Year    Species     Sex CWD_Status
# 0      100  Saskatchewan  2000  Mule Deer    Male   Positive
# 1      101  Saskatchewan  2001  Mule Deer    Male   Positive
# 2      102  Saskatchewan  2002  Mule Deer    Male   Positive
# 3      103  Saskatchewan  2003  Mule Deer  Female   Positive
# 4      104  Saskatchewan  2004  Mule Deer    Male   Positive

# %%
#Renaming columns so headers will match for append. Year is keyword in SQL so had to rename column to load.
cwd_2011_2013_df = cwd_2011_2013_df.rename(columns={"Case":"Case_ID", "Year": "Years"})
cwd_2011_2013_df.head()
# Out:
#    Case_ID  Year  Easting  Northing CWD_Status            Species     Sex
# 0    10000  2011   432845   5849162   Negative  White-tailed Deer    Male
# 1    10001  2011   429500   5868700   Negative  White-tailed Deer    Male
# 2    10002  2011   438723   5896022   Negative  White-tailed Deer    Male
# 3    10003  2011   428623   5862820   Negative          Mule Deer    Male
# 4    10004  2011   431230   5882820   Negative          Mule Deer  Female

# %%
#Test of utm coordinates to lat lon
utm.to_latlon(548750.7613, 5826273.207, 12, "N")
# Out:
# (52.584309997959735, -110.28045998665556)

# %%
#Taking UTM x y coordinates with zone 12 N and converting it into LAT LON then converting that into the missing province data.
easting = []
northing = []
latitude = []
longitude = []
address = []
province =[]

easting = cwd_2011_2013_df["Easting"]
northing = cwd_2011_2013_df["Northing"]

for i in range(0, len(easting)):
   latlong = utm.to_latlon(easting[i], northing[i], 12, "N")


   def reverseGeocode(latlong):
     result = rg.search(latlong)
     address.append(result)
    
   if __name__=="__main__":
     reverseGeocode(latlong)

   province.append(address[i][0]["admin1"])
# Out:
# Loading formatted geocoded file...

# %%
#Creating our last missing piece of data as a new column
cwd_2011_2013_df['Province']= province

cwd_2011_2013_df
# Out:
#       Case_ID  Year  Easting  Northing CWD_Status            Species     Sex  \
# 0       10000  2011   432845   5849162   Negative  White-tailed Deer    Male
# 1       10001  2011   429500   5868700   Negative  White-tailed Deer    Male
# 2       10002  2011   438723   5896022   Negative  White-tailed Deer    Male
# 3       10003  2011   428623   5862820   Negative          Mule Deer    Male
# 4       10004  2011   431230   5882820   Negative          Mule Deer  Female
# 5       10005  2011   444623   5897822   Negative          Mule Deer  Female
# 6       10006  2011   428592   5872368   Negative          Mule Deer  Female
# 7       10007  2011   445655   5870519   Negative  White-tailed Deer    Male
# 8       10008  2011   430831   5881672   Negative  White-tailed Deer    Male
# 9       10009  2011   430200   5867300   Negative  White-tailed Deer    Male
# 10      10010  2011   426423   5857920   Negative  White-tailed Deer    Male
# 11      10011  2011   438723   5896022   Negative  White-tailed Deer  Female
# 12      10012  2011   430131   5867041   Negative          Mule Deer    Male
# 13      10013  2011   469823   5811220   Negative  White-tailed Deer    Male
# 14      10014  2011   655418   5911974   Negative          Mule Deer  Female
# 15      10015  2011   517933   5797196   Negative          Mule Deer  Female
# 16      10016  2011   483198   5858918   Negative          Mule Deer  Female
# 17      10017  2011   496680   5806873   Negative          Mule Deer  Female
# 18      10018  2011   507624   5852417   Negative          Mule Deer    Male
# 19      10019  2011   507624   5852417   Negative          Mule Deer  Female
# 20      10020  2011   646604   5907662   Negative  White-tailed Deer    Male
# 21      10021  2011   553529   5619920   Negative          Mule Deer    Male
# 22      10022  2011   524861   5785903   Negative  White-tailed Deer  Female
# 23      10023  2011   478683   5896985   Negative          Mule Deer  Female
# 24      10024  2011   478683   5896985   Negative          Mule Deer    Male
# 25      10025  2011   564599   5490117   Negative  White-tailed Deer    Male
# 26      10026  2011   495427   5685170   Negative          Mule Deer    Male
# 27      10027  2011   489736   5653943   Negative  White-tailed Deer    Male
# 28      10028  2011   545015   5489893   Negative          Mule Deer  Female
# 29      10029  2011   565792   5645520   Negative          Mule Deer    Male
# ...       ...   ...      ...       ...        ...                ...     ...
# 9298    19298  2011   500000   5800000   Positive          Mule Deer  Female
# 9299    19299  2011   500000   5800000   Positive          Mule Deer  Female
# 9300    19300  2011   560000   5800000   Positive          Mule Deer  Female
# 9301    19301  2011   570000   5640000   Positive          Mule Deer    Male
# 9302    19302  2011   500000   5820000   Positive          Mule Deer  Female
# 9303    19303  2011   550000   5720000   Positive          Mule Deer    Male
# 9304    19304  2011   570000   5610000   Positive          Mule Deer    Male
# 9305    19305  2011   540000   5520000   Positive  White-tailed Deer    Male
# 9306    19306  2011   540000   5790000   Positive          Mule Deer  Female
# 9307    19307  2011   560000   5720000   Positive          Mule Deer    Male
# 9308    19308  2011   490000   5620000   Positive          Mule Deer    Male
# 9309    19309  2011   460000   5800000   Positive          Mule Deer    Male
# 9310    19310  2011   500000   5800000   Positive          Mule Deer  Female
# 9311    19311  2011   530000   5840000   Positive          Mule Deer    Male
# 9312    19312  2011   570000   5610000   Positive  White-tailed Deer    Male
# 9313    19313  2011   560000   5620000   Positive          Mule Deer  Female
# 9314    19314  2011   560000   5630000   Positive          Mule Deer    Male
# 9315    19315  2011   540000   5640000   Positive  White-tailed Deer    Male
# 9316    19316  2011   570000   5620000   Positive          Mule Deer    Male
# 9317    19317  2011   540000   5840000   Positive          Mule Deer    Male
# 9318    19318  2011   500000   5830000   Positive          Mule Deer  Female
# 9319    19319  2011   550000   5630000   Positive          Mule Deer    Male
# 9320    19320  2011   480000   5800000   Positive          Mule Deer    Male
# 9321    19321  2011   500000   5800000   Positive          Mule Deer  Female
# 9322    19322  2011   570000   5620000   Positive          Mule Deer    Male
# 9323    19323  2011   490000   5850000   Positive          Mule Deer    Male
# 9324    19324  2011   540000   5620000   Positive          Mule Deer    Male
# 9325    19325  2011   500000   5640000   Positive          Mule Deer    Male
# 9326    19326  2011   550000   5680000   Positive          Mule Deer  Female
# 9327    19327  2011   510000   5750000   Positive          Mule Deer    Male
#
#           Province
# 0          Alberta
# 1          Alberta
# 2          Alberta
# 3          Alberta
# 4          Alberta
# 5          Alberta
# 6          Alberta
# 7          Alberta
# 8          Alberta
# 9          Alberta
# 10         Alberta
# 11         Alberta
# 12         Alberta
# 13         Alberta
# 14    Saskatchewan
# 15         Alberta
# 16         Alberta
# 17         Alberta
# 18         Alberta
# 19         Alberta
# 20    Saskatchewan
# 21         Alberta
# 22         Alberta
# 23         Alberta
# 24         Alberta
# 25    Saskatchewan
# 26         Alberta
# 27         Alberta
# 28         Alberta
# 29    Saskatchewan
# ...            ...
# 9298       Alberta
# 9299       Alberta
# 9300       Alberta
# 9301  Saskatchewan
# 9302       Alberta
# 9303       Alberta
# 9304       Alberta
# 9305       Alberta
# 9306       Alberta
# 9307  Saskatchewan
# 9308       Alberta
# 9309       Alberta
# 9310       Alberta
# 9311       Alberta
# 9312       Alberta
# 9313       Alberta
# 9314       Alberta
# 9315       Alberta
# 9316       Alberta
# 9317       Alberta
# 9318       Alberta
# 9319       Alberta
# 9320       Alberta
# 9321       Alberta
# 9322       Alberta
# 9323       Alberta
# 9324       Alberta
# 9325       Alberta
# 9326       Alberta
# 9327       Alberta
#
# [9328 rows x 8 columns]

# %%
#Saving our data from above into csv because the for loop takes a while to run on certain machines.
cwd_2011_2013_df.to_csv('./Output/New_2011_2013.csv')

# %%
#Usable once the for loop has been run once so that you don't need to run that step again to continue the transformation.

# csv_file = "./Output/New_2011_2013.csv"
# new_cwd_2011_2013_df = pd.read_csv(csv_file)
# new_cwd_2011_2013_df

# %%
#No longer need these columns and must remove to append.
new_cwd_2011_2013_df = cwd_2011_2013_df.drop(['Easting', 'Northing'], axis=1)
new_cwd_2011_2013_df.head()
# Out:
#    Case_ID  Year CWD_Status            Species     Sex Province
# 0    10000  2011   Negative  White-tailed Deer    Male  Alberta
# 1    10001  2011   Negative  White-tailed Deer    Male  Alberta
# 2    10002  2011   Negative  White-tailed Deer    Male  Alberta
# 3    10003  2011   Negative          Mule Deer    Male  Alberta
# 4    10004  2011   Negative          Mule Deer  Female  Alberta

# %%
#Appending the two DataFrames together into one so the new transformed file is ready to load into SQL.
cwd_2000_2013_df = new_cwd_2000_2010_df.append(new_cwd_2011_2013_df)
cwd_2000_2013_df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#   CWD_Status  Case_ID      Province     Sex    Species  Year
# 0   Positive      100  Saskatchewan    Male  Mule Deer  2000
# 1   Positive      101  Saskatchewan    Male  Mule Deer  2001
# 2   Positive      102  Saskatchewan    Male  Mule Deer  2002
# 3   Positive      103  Saskatchewan  Female  Mule Deer  2003
# 4   Positive      104  Saskatchewan    Male  Mule Deer  2004

# %%
#Checking Data
cwd_2000_2013_df.tail()
# Out:
#      CWD_Status  Case_ID Province     Sex    Species  Year
# 9323   Positive    19323  Alberta    Male  Mule Deer  2011
# 9324   Positive    19324  Alberta    Male  Mule Deer  2011
# 9325   Positive    19325  Alberta    Male  Mule Deer  2011
# 9326   Positive    19326  Alberta  Female  Mule Deer  2011
# 9327   Positive    19327  Alberta    Male  Mule Deer  2011

# %%
#Checking Data
cwd_2000_2013_df['Year'].value_counts()
# Out:
# 2008    5653
# 2007    5334
# 2009    3461
# 2013    3154
# 2011    3108
# 2012    3089
# 2010    2848
# 2006    1779
# 2005     446
# 2004       4
# 2003       1
# 2002       1
# 2001       1
# 2000       1
# Name: Year, dtype: int64

# %%
#Saving our combined data.
cwd_2000_2013_df.to_csv('./Output/2000_2013.csv')

# %% [markdown]
# # Load: the final database, tables/collections.

# %% [markdown]
# ### Connect to local database

# %%
rds_connection_string = "root:<insert password>@127.0.0.1/deer_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %% [markdown]
# ### Check for tables

# %%
engine.table_names()

# %% [markdown]
# ### Use pandas to load csv converted DataFrames into database

# %%
cwd_2000_2013_df.to_sql(name='deercwd', con=engine, if_exists='append', index=False)

# %%
census_df.to_sql(name='census', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### Confirm data has been added by querying the deercwd & census
# * NOTE: can also check using pgAdmin

# %%
pd.read_sql_query('select * from deercwd', con=engine).head()

# %%
pd.read_sql_query('select * from census', con=engine).head()
